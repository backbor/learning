# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Формулирование-задачи" data-toc-modified-id="Формулирование-задачи-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Формулирование задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Загрузка-и-обзор-данных" data-toc-modified-id="Загрузка-и-обзор-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Загрузка и обзор данных</a></span></li><li><span><a href="#Подитог:" data-toc-modified-id="Подитог:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Подитог:</a></span></li></ul></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка</a></span><ul class="toc-item"><li><span><a href="#Датасет-df_market_file" data-toc-modified-id="Датасет-df_market_file-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Датасет df_market_file</a></span></li><li><span><a href="#Датасет-df_market_money" data-toc-modified-id="Датасет-df_market_money-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Датасет df_market_money</a></span></li><li><span><a href="#Датасет-df_market_time" data-toc-modified-id="Датасет-df_market_time-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Датасет df_market_time</a></span></li><li><span><a href="#Датасет-df_money" data-toc-modified-id="Датасет-df_money-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Датасет df_money</a></span></li><li><span><a href="#Подитог-по-разделу:" data-toc-modified-id="Подитог-по-разделу:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подитог по разделу:</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Датасет-df_market_file" data-toc-modified-id="Датасет-df_market_file-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Датасет df_market_file</a></span></li><li><span><a href="#Датасет-df_market_money" data-toc-modified-id="Датасет-df_market_money-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Датасет df_market_money</a></span></li><li><span><a href="#Датасет-df_market_time" data-toc-modified-id="Датасет-df_market_time-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Датасет df_market_time</a></span></li><li><span><a href="#Датасет-df_money" data-toc-modified-id="Датасет-df_money-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Датасет df_money</a></span></li></ul></li><li><span><a href="#Обьединение-таблиц" data-toc-modified-id="Обьединение-таблиц-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обьединение таблиц</a></span><ul class="toc-item"><li><span><a href="#Подитог." data-toc-modified-id="Подитог.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Подитог.</a></span></li></ul></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Корреляционный анализ</a></span><ul class="toc-item"><li><span><a href="#Заключение-по-корреляционному-анализу." data-toc-modified-id="Заключение-по-корреляционному-анализу.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Заключение по корреляционному анализу.</a></span></li></ul></li><li><span><a href="#Использование-пайплайнов" data-toc-modified-id="Использование-пайплайнов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Использование пайплайнов</a></span><ul class="toc-item"><li><span><a href="#Пайплайн-для-подготовки-данных-с-использованием-ColumnTransformer" data-toc-modified-id="Пайплайн-для-подготовки-данных-с-использованием-ColumnTransformer-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Пайплайн для подготовки данных с использованием ColumnTransformer</a></span></li><li><span><a href="#Пайплайн-для-поиска-лучшей-модели-c--подбором-гиперпараметров" data-toc-modified-id="Пайплайн-для-поиска-лучшей-модели-c--подбором-гиперпараметров-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Пайплайн для поиска лучшей модели c  подбором гиперпараметров</a></span></li><li><span><a href="#Подитог" data-toc-modified-id="Подитог-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Подитог</a></span></li></ul></li><li><span><a href="#Анализ-важности-признаков.-Shap" data-toc-modified-id="Анализ-важности-признаков.-Shap-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ важности признаков. Shap</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-анализу-важности-признаков" data-toc-modified-id="Выводы-по-анализу-важности-признаков-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Выводы по анализу важности признаков</a></span></li></ul></li><li><span><a href="#Сегментация-покупателей" data-toc-modified-id="Сегментация-покупателей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сегментация покупателей</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ##  Описание проекта
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# ###  Формулирование задачи
# Разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
# 1.	Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 2.	Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 3.	В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 4.	Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# ### Описание данных
#
# Данные для работы находятся в нескольких таблицах. Нажмите на название файла, чтобы его скачать.
# **market_file.csv**
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - 	`Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# -	`Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# -	`Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - 	`Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# -	`Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# -	`Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# -	`Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# -	`Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# -	`Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# 	`Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# -	`Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# **market_money.csv**
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# -	`id` — номер покупателя в корпоративной базе данных.
# -	`Период` — название периода, во время которого зафиксирована выручка. Например,
# 'текущий_месяц' или 'предыдущий_месяц'.
# -	`Выручка` — сумма выручки за период.
#
# **market_time.csv**
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# -	`id` — номер покупателя в корпоративной базе данных.
# -	`Период` — название периода, во время которого зафиксировано общее время.
# -	`минут` — значение времени, проведённого на сайте, в минутах.
#
# **money.csv**
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# -	`id` — номер покупателя в корпоративной базе данных.
# -	`Прибыль` — значение прибыли.
#
#
# План работы:
#
# - Шаг 1. Загрузка данных и необходимых иструментов
# - Шаг 2. Предобработка данных
# - Шаг 3. Исследовательский анализ данных
# - Шаг 4. Объединение таблиц
# - Шаг 5. Корреляционный анализ
# - Шаг 6. Использование пайплайнов
# - Шаг 7. Анализ важности признаков
# - Шаг 8. Сегментация покупателей
# - Шаг 9. Общий вывод

# %%
#установка необходимых библиотек
# !pip install shap -q
# !pip install phik -q

# %%
#необходимые импорты
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import plotly.express as pe
import os
import time
import math


#Классы для подготовки данных
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer
#Класс для работы с пропусками
from sklearn.impute import SimpleImputer

#Классы моделей классификации
from sklearn.linear_model import LogisticRegression#, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

#Класс Бейсовской оптимизации гиперпараметров.
#from optuna.integration import OptunaSearchCV 
#Класс случайной оптимизации гиперпараметров RandomizedSearchCV и  GridSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

#from sklearn.ensemble import RandomForestRegressor

#Классы метрик
from sklearn.metrics import (
                             roc_auc_score,
                             f1_score,
                             precision_score,
                             recall_score,
                             accuracy_score,
                             confusion_matrix,
                             precision_recall_curve,
                            )


#from scipy import stats as st
#from scipy.stats import pointbiserialr, fisher_exact, chi2_contingency

#from statsmodels.stats.outliers_influence import variance_inflation_factor
# Импорт phik
import phik
from phik import phik_matrix
from phik.report import plot_correlation_matrix

import shap

# %% [markdown]
# ### Загрузка и обзор данных

# %%
try:
    df_market_file = pd.read_csv('market_file.csv',  sep=',',decimal='.') 
    df_market_money = pd.read_csv('market_money.csv',  sep=',',decimal='.' )
    df_market_time = pd.read_csv('market_time.csv',  sep=',')
    df_money = pd.read_csv('money.csv', sep=';',decimal=',')
except:
    df_market_file = pd.read_csv('/datasets/market_file.csv',  sep=',',decimal='.') 
    df_market_money = pd.read_csv('/datasets/market_money.csv',  sep=',',decimal='.' )
    df_market_time = pd.read_csv('/datasets/market_time.csv',  sep=',')
    df_money = pd.read_csv('/datasets/money.csv', sep=';',decimal=',')

# %%
def data_primary_observe (df):
    pd.set_option('display.max_columns', None)
    if df.shape[0] <10:
        df_head = df.head()
    else:
        df_head = df.sample(10, random_state=5)
    display ('Несколько строк датафрейма:', df_head)
    display('*'*50)
    display ('Общая информация по датафрему:')
    df_info = df.info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None, null_counts=None) #verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None, null_counts=None)
    
    print('*'*50)
    #df_describe = df.describe()
    #df_hist = df.hist(figsize=(15, 20));
    #duplicate_quantity = 'Количество явных дубликатов = '+ str(df.duplicated().sum())+'\n' +'*'*50  #проверка наличия явных дубликатов
    #duplicate_quantity =' '.join(['Количество явных дубликатов =', str(df.duplicated().sum()), os.linesep, '*'*50])
    duplicate_quantity = 'Количество явных дубликатов = '+ str(df.duplicated().sum())
    return duplicate_quantity# display (df_head, df_info,  duplicate_quantity)

# %%
data_primary_observe (df_market_file)
# Out:
# 'Несколько строк датафрейма:'
#           id Покупательская активность Тип сервиса Разрешить сообщать  \
# 591   215939                 Снизилась    стандарт                 да
# 495   215843                 Снизилась    стандарт                 да
# 267   215615                 Снизилась    стандарт                 да
# 1276  216624           Прежний уровень    стандарт                 да
# 730   216078           Прежний уровень    стандарт                 да
# 347   215695                 Снизилась    стандарт                 да
# 1173  216521           Прежний уровень    стандарт                 да
# 1157  216505           Прежний уровень    стандарт                нет
# 34    215382                 Снизилась    стандарт                 да
# 288   215636                 Снизилась    стандарт                 да
#
#       Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# 591                  2.6                     3           966
# ...

# %% [markdown]
# Пропуски данных и явные дубликаты отсутствуют. Имена колонок требуется привести к стандартным требованиям.

# %%
data_primary_observe (df_market_money)
# Out:
# 'Несколько строк датафрейма:'
#           id               Период  Выручка
# 3069  216371     предыдущий_месяц   5362.5
# 1195  215746     предыдущий_месяц   3222.0
# 1015  215686     предыдущий_месяц   4828.0
# 76    215373  препредыдущий_месяц   4293.0
# 1201  215748     предыдущий_месяц   5083.0
# 47    215363  препредыдущий_месяц   4633.0
# 814   215619        текущий_месяц   5543.4
# 3862  216635        текущий_месяц   5039.6
# 2716  216253     предыдущий_месяц   5236.0
# 743   215595  препредыдущий_месяц   4751.0
# '**************************************************'
# 'Общая информация по датафрему:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# ...

# %% [markdown]
# Пропуски данных и явные дубликаты отсутствуют. Имена колонок требуется привести к стандартным требованиям.

# %%
data_primary_observe (df_market_time)
# Out:
# 'Несколько строк датафрейма:'
#           id            Период  минут
# 1958  216327     текущий_месяц     20
# 976   215836  предыдцщий_месяц     12
# 194   215445  предыдцщий_месяц      9
# 1724  216210  предыдцщий_месяц     21
# 767   215731  предыдцщий_месяц      9
# 1208  215952     текущий_месяц     13
# 2270  216483     текущий_месяц     17
# 2342  216519  предыдцщий_месяц     15
# 1499  216097  предыдцщий_месяц     15
# 952   215824     текущий_месяц     12
# '**************************************************'
# 'Общая информация по датафрему:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# **************************************************
# ...

# %%
data_primary_observe (df_money)
# Out:
# 'Несколько строк датафрейма:'
#           id  Прибыль
# 591   215939     2.57
# 495   215843     4.68
# 267   215615     4.17
# 1276  216624     3.72
# 730   216078     2.97
# 347   215695     4.36
# 1173  216521     4.15
# 1157  216505     5.08
# 34    215382     2.42
# 288   215636     4.64
# '**************************************************'
# 'Общая информация по датафрему:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# **************************************************
# 'Количество явных дубликатов = 0'

# %% [markdown]
# ### Подитог:
# Пропуски данных и явные дубликаты отсутствуют. Имена колонок требуется привести к стандартным требованиям.

# %% [markdown]
# ## Предобработка

# %% [markdown]
# ### Датасет df_market_file

# %%
df_market_file.columns=df_market_file.columns.str.replace(' ', '_') 
df_market_file.columns=df_market_file.columns.str.lower()

# %%
#Поищем неявные дубликаты
cat_col_names = df_market_file.select_dtypes(exclude='number').columns.tolist()
for i in cat_col_names:
    print(i,'\n', df_market_file[i].value_counts(), '\n')
# Out:
# покупательская_активность
#  Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
#
# тип_сервиса
#  стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
# разрешить_сообщать
#  да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
#
# популярная_категория
#  Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %% [markdown]
# нашлись неявные дубликаты в 'тип_сервиса' обработаем

# %%
df_market_file['тип_сервиса']=df_market_file['тип_сервиса'].str.replace('тт', 'т')

# %% [markdown]
# Подитог: Имена колонок приведены к стандартному виду, обработаны неявные дубликаты.

# %% [markdown]
# ### Датасет df_market_money

# %%
df_market_money.columns
# Out:
# Index(['id', 'Период', 'Выручка'], dtype='object')

# %%
df_market_money.columns=df_market_money.columns.str.lower()
df_market_money['период'].value_counts()
# Out:
# препредыдущий_месяц    1300
# предыдущий_месяц       1300
# текущий_месяц          1300
# Name: период, dtype: int64

# %% [markdown]
# ###  Датасет df_market_time

# %%
df_market_time.columns=df_market_time.columns.str.lower()
df_market_time['период'].value_counts()
# Out:
# предыдцщий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64

# %%
df_market_time['период']=df_market_time['период'].str.replace('дц', 'ду')

# %%
df_market_time['период'].value_counts()
# Out:
# предыдущий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64

# %% [markdown]
# ###  Датасет df_money

# %%
df_money.columns=df_money.columns.str.lower()

# %% [markdown]
# ### Подитог по разделу:
# - Переименованы колонки в соответсвии со стандартными требованиями.
# - Обработаны обнаруженные неявные дубликаты в категориальных признаках.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
#ф-ия обзора вещественных признаков
def hist_with_stat_lines(df, df_col, dtitle, dxlabel, dylabel, bins = 0, kde=False):
    df_col_description =  df_col.describe()
    mean = df_col_description[1]
    std = df_col_description[2]
    df_min = df_col_description[3]
    q1 = df_col_description[4]
    median = df_col_description[5]
    q3 = df_col_description[6]
    df_max = df_col_description[7]
    iqr = (q3-q1)+0.1 
    left_border = q1 - iqr*1.5
    # усы обрезаются минимальным и максимальным значением параметра сооветственно
    if left_border < df_min:
        left_border = df_min
    right_border = q3 + iqr*1.5
    if right_border > df_max:
        right_border = df_max
        
    if bins == 0:
        bins = right_border - left_border
        if bins>100:
            bins = 100
        elif bins<1:
            bins = bins*20
        elif bins>1 and bins<5:
            bins = 5
        bins = int(bins)
    else:
        bins = bins
        
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    fig.suptitle(dtitle)   
    fig = sns.histplot(df, x=df_col, bins=bins, kde=kde, ax=axes[0]  ) # binwidth = bins/10 #kde=True  edgecolor='g' bins=bins  binwidth = bins/50
    axes[0].set_title('Гистограмма распределения')
    fig.set(xlim=(left_border, right_border)) 
    ax = sns.boxplot(x=df_col, data=df, ax=axes[1])
    ax = sns.stripplot(x=df_col, data=df, color="orange", jitter=0.2, size=2.5, ax=axes[1])
    axes[1].set_title('"Ящик с усами +"')
    #plt.title(dtitle)
    #plt.xlabel(dxlabel)
    axes[0].set_ylabel(dylabel)
    axes[0].set_xlabel(dxlabel)
    axes[1].set_xlabel(dxlabel)
    #axes[0].set.
    #plt.ylabel(dylabel)
    #fig.supxlabel(dxlabel)
    axes[0].axvline(x=mean,linewidth=1, color='r', linestyle='-' , label= 'mean_value')
    axes[0].axvline(x=median,linewidth=1, color='b', linestyle='-', label= 'median_value')
    axes[0].axvline(x=q1,linewidth=1, color='g', linestyle='--',label= 'Q1_value')
    axes[0].axvline(x=q3,linewidth=1, color='g', linestyle='--',label= 'Q3_value')
    #plt.legend(loc = 'best')
    axes[0].legend(loc = 'best')
    #fig.suptitle(dtitle, fontsize = 13) ;
    return print ('Статистические параметры колонки данных' ,dxlabel,'\n' ,'\n',  df_col_description,'\n')# df_col_description

# %% [markdown]
# ### Датасет df_market_file

# %%
hist_with_stat_lines(df_market_file, df_market_file['маркет_актив_6_мес'], 
                     'Анализ среднемесячного к-ва маркетинговых коммуникаций с покупателем за последние 6 месяцев', 
                     'К-во маркетинговых коммуникаций',
                     'Количество записей',0,True)
#№df, df_col, dtitle, dxlabel, dylabel, bins
# Out:
# Статистические параметры колонки данных К-во маркетинговых коммуникаций
#
#  count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64

# %% [markdown]
# Признак распределен близко к нормальному. Низкие значения аретефактами не являются.

# %%
df_market_file['маркет_актив_тек_мес'].describe()
# Out:
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %%
#df_market_file['маркет_актив_тек_мес'].describe()
hist_with_stat_lines(df_market_file, df_market_file['маркет_актив_тек_мес'], 
                     'Анализ количества маркетинговых коммуникаций в текущем месяце', 
                     'К-во маркетинговых коммуникаций',
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во маркетинговых коммуникаций
#
#  count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %% [markdown]
# Всего три значения...

# %%
hist_with_stat_lines(df_market_file, df_market_file['длительность'], \
                     'Анализ длительности регистрации пользователя ', 'длительность, дни', 'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных длительность, дни
#
#  count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %% [markdown]
# Длительность без особенностей

# %%
hist_with_stat_lines(df_market_file, df_market_file['акционные_покупки'], \
                     'Анализ среднемесячной доли покупок по акции',
                     'Доля покупок по акции за последние 6 месяцев', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Доля покупок по акции за последние 6 месяцев
#
#  count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64

# %% [markdown]
# Выделяются 2 кластера, второй немногочисленный с высоким значением, что не являтся артефактом, есть часть покупателей которая использует сайт только для акционных покупок.

# %%
hist_with_stat_lines(df_market_file, df_market_file['средний_просмотр_категорий_за_визит'], \
                     'Анализ Среднего за месяц количества просмотров категорий за визит',
                     'Среднее количество просмотров категорий', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Среднее количество просмотров категорий
#
#  count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         6.00000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %% [markdown]
# Дискретный признак, артефактов нет.

# %%
hist_with_stat_lines(df_market_file, df_market_file['неоплаченные_продукты_штук_квартал'], \
                     'Анализ  К-ва неоплаченных товаров в корзине за последние 3 месяца',
                     'К-во неоплаченных товаров', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во неоплаченных товаров
#
#  count    1300.000000
# mean        2.840000
# std         1.971451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %% [markdown]
# Тоже дискретный признак, без артефактов.

# %%
hist_with_stat_lines(df_market_file, df_market_file['ошибка_сервиса'], \
                     'Анализ к-ва сбоев, которые коснулись покупателя во время посещения сайта',
                     'К-во сбоев', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во сбоев
#
#  count    1300.000000
# mean        4.185385
# std         1.955298
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64

# %% [markdown]
# Дискретное нормальное распредеение

# %%
hist_with_stat_lines(df_market_file, df_market_file['страниц_за_визит'], \
                     'Анализ среднего количества страниц, посещенных покупателем за один визит на сайт за 3 месяца',
                     'К-во  страниц', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных К-во  страниц
#
#  count    1300.000000
# mean        8.176923
# std         3.978126
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64

# %% [markdown]
# Медиана и среденне около 8 страниц

# %% [markdown]
# ### Датасет df_market_money
# Рассмотрим выручку по периодам

# %%
for i in df_market_money['период'].unique():
    df_period = df_market_money.query('период == @i')['выручка']
    hist_with_stat_lines(df_period, df_period, 
                     'Анализ распределения выручки за период '+i,
                     'Сумма выручки за '+i, 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Сумма выручки за препредыдущий_месяц
#
#  count    1300.000000
# mean     4825.206923
# std       405.979663
# min         0.000000
# 25%      4583.000000
# 50%      4809.000000
# 75%      5053.500000
# max      5663.000000
# Name: выручка, dtype: float64
#
# Статистические параметры колонки данных Сумма выручки за текущий_месяц
#
#  count      1300.000000
# mean       5314.960846
# std        2939.708156
# min        2758.700000
# 25%        4706.050000
# 50%        5179.950000
# 75%        5761.725000
# max      106862.200000
# Name: выручка, dtype: float64
#
# Статистические параметры колонки данных Сумма выручки за предыдущий_месяц
#
#  count    1300.000000
# mean     4936.920385
# std       739.597997
# min         0.000000
# 25%      4496.750000
# 50%      5005.000000
# 75%      5405.625000
# max      6869.500000
# Name: выручка, dtype: float64

# %% [markdown]
# По результатам данного анализа сделаю вывод,  если сумма выручки = 0 это скорее нормально, а вот на порядок отличающееся значение выручки за период текущий месяц заменим медианой.
# Возможно  лучше и нули заменить медианой, но не уверен.

# %%
df_market_money.loc[df_market_money['выручка'] > 20000 , 'выручка'] = \
    df_market_money['выручка'].median()

# %%
df_market_money_copy= df_market_money.copy()
df_market_money = df_market_money.query('выручка != 0')

# %% [markdown]
# ###  Датасет df_market_time

# %%
for i in df_market_time['период'].unique():
    df_period = df_market_time.query('период == @i')['минут']
    hist_with_stat_lines(df_period, df_period, 
                     'Анализ распределения времени, проведённого на сайте, в минутах за '+i,
                     'Время, проведённое на сайте за '+i, 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Время, проведённое на сайте за текущий_месяц
#
#  count    1300.000000
# mean       13.204615
# std         4.220589
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64
#
# Статистические параметры колонки данных Время, проведённое на сайте за предыдущий_месяц
#
#  count    1300.000000
# mean       13.467692
# std         3.932029
# min         5.000000
# 25%        11.000000
# 50%        13.000000
# 75%        17.000000
# max        23.000000
# Name: минут, dtype: float64

# %% [markdown]
# Нормально распределенные данные

# %% [markdown]
# ###  Датасет df_money

# %%
hist_with_stat_lines(df_money, df_money['прибыль'], 
                     'Анализ распределения среднемесячной прибыли от продаж каждому покупателю за последние 3 месяца ',
                     'Прибыль', 
                     'Количество записей',0,True)
# Out:
# Статистические параметры колонки данных Прибыль
#
#  count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %% [markdown]
# Нормально распределнный признак

# %% [markdown]
# После обьединения таблиц проведем сравнение  влияние признаков для задачи класификации, построив графики распределений в разбивке по таргету - "Покупательская активность".

# %% [markdown]
# ## Обьединение таблиц
# Произведем обьеденение данных в 2 этапа.
# - 1. Добавим выручку из df_market_money в df_market_file
# Как мы знаем из ознакомления с данными, датасет df_market_money содержит выручку по пользователям за 3 месяца по 1300 значений в каждом. Добавим на первом этапе данные к основному датасету  df_market_file отдельными столбцами по каждому из 3 месяцев.
# - 2. Добавим данные о времени проведенном на сайте из df_market_time в df_market_file
# Датасет df_market_time содержит информацию  за 2 месяца по 1300 значений в каждом. Поступим аналогично добавим  данные к основному датасету  df_market_file отдельными столбцами по каждому из 2 месяцев.

# %%
#проверим на наличие непересекающихся id
df_market_file_copy = df_market_file.copy()
df_market_file['id'][~df_market_file['id'].isin(df_market_money['id'])]
# Out:
# Series([], Name: id, dtype: int64)

# %%
df_market_file['id'][~df_market_file['id'].isin(df_market_time['id'])]
# Out:
# Series([], Name: id, dtype: int64)

# %%
#Добавим выручку из df_market_money в df_market_file
for i in df_market_money['период'].unique():
    df_i ='df_'+i
    df_i = df_market_money.query('период == @i')
    df_i = df_i.drop(['период'], axis=1)
    earn = 'выручка_за_'+i
    df_i.rename(columns={'выручка': earn}, inplace=True)
    df_market_file = pd.merge(df_market_file, df_i, how="right", on="id")

# %%
#Аналогично добавим данные о времени проведенном на сайте из df_market_time в df_market_file
for i in df_market_time['период'].unique():
    df_i ='df_'+i
    df_i = df_market_time.query('период == @i')
    df_i = df_i.drop(['период'], axis=1)
    earn = 'минут_за_'+i
    df_i.rename(columns={'минут': earn}, inplace=True)
    df_market_file = pd.merge(df_market_file, df_i, how="left", on="id")

# %%
#Убедимся, что процедуры прошли нормально
data_primary_observe(df_market_file)
# Out:
# 'Несколько строк датафрейма:'
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 590   215941                 Снизилась    стандарт                 да
# 492   215843                 Снизилась    стандарт                 да
# 267   215618                 Снизилась    стандарт                нет
# 1274  216625           Прежний уровень    стандарт                 да
# 1246  216597           Прежний уровень    стандарт                 да
# 630   215981           Прежний уровень    стандарт                 да
# 1171  216522           Прежний уровень    стандарт                 да
# 1146  216497           Прежний уровень    стандарт                 да
# 34    215385                 Снизилась    стандарт                 да
# 288   215639                 Снизилась     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 590                  3.3                     5           157
# ...

# %%
df_market_time.head(2)
# Out:
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдущий_месяц     13

# %%
data1=df_market_time.pivot_table(index='id', columns='период', values='минут')


#data1.columns = data1.columns.get_level_values(0) # - как вариант

data1=data1.rename_axis(None)
data1.columns = ['предыдущий_месяц_минут', 'текущий_месяц_минут']


data1.head(2)
# Out:
#         предыдущий_месяц_минут  текущий_месяц_минут
# 215348                      13                   14
# 215349                      12                   10

# %%
pivot_dfmoney = df_market_money_copy.pivot_table(index='id', columns='период', values='выручка')

pivot_dfmoney = pivot_dfmoney.query('предыдущий_месяц != 0 and препредыдущий_месяц !=0 and\
                                     текущий_месяц !=0')
pivot_dfmoney.rename(columns={'предыдущий_месяц': 'выручка_за_предыдущий_месяц', \
                                              'препредыдущий_месяц': 'выручка_за_препредыдущий_месяц', \
                                              'текущий_месяц': 'выручка_за_текущий_месяц'}, inplace=True)
pivot_dftime = df_market_time.pivot_table(index='id', columns='период', values='минут')
pivot_dftime.rename(columns={'предыдущий_месяц': 'минут_за_предыдущий_месяц', \
                                              'текущий_месяц': 'минут_за_текущий_месяц'}, inplace=True)

df_market_file_new = pd.merge(df_market_file_copy, pivot_dfmoney, how="right", on="id")
df_market_file_new = pd.merge(df_market_file_new, pivot_dftime, how="left", on="id")
data_primary_observe(df_market_file_new)
# Out:
# 'Несколько строк датафрейма:'
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 590   215941                 Снизилась    стандарт                 да
# 492   215843                 Снизилась    стандарт                 да
# 267   215618                 Снизилась    стандарт                нет
# 1274  216625           Прежний уровень    стандарт                 да
# 1246  216597           Прежний уровень    стандарт                 да
# 630   215981           Прежний уровень    стандарт                 да
# 1171  216522           Прежний уровень    стандарт                 да
# 1146  216497           Прежний уровень    стандарт                 да
# 34    215385                 Снизилась    стандарт                 да
# 288   215639                 Снизилась     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 590                  3.3                     5           157
# ...

# %% [markdown]
# ### Подитог.
# Объединение данных прошло успешно.

# %% [markdown]
# ## Корреляционный анализ
# Выполним данный анализ с использованием phik

# %%
#num_col_names

# %%
#удалим id
#num_col_names_for_cor_matrix  = [x for x in num_col_names if x not in ['id']]
df_market_file_new_ = df_market_file_new.drop('id', axis=1)
#создаём список с наименованиями дискретных и непрерывных признаков
num_col_names = df_market_file_new_.select_dtypes(include='number').columns.tolist()
num_col_names
# Out:
# ['маркет_актив_6_мес',
#  'маркет_актив_тек_мес',
#  'длительность',
#  'акционные_покупки',
#  'средний_просмотр_категорий_за_визит',
#  'неоплаченные_продукты_штук_квартал',
#  'ошибка_сервиса',
#  'страниц_за_визит',
#  'выручка_за_предыдущий_месяц',
#  'выручка_за_препредыдущий_месяц',
#  'выручка_за_текущий_месяц',
#  'минут_за_предыдущий_месяц',
#  'минут_за_текущий_месяц']

# %%
#матрица корреляций
phik_overview = phik_matrix(df_market_file_new_, interval_cols=num_col_names)
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# В порядке убывания силы корреляции с целевым `"признаком покупательская_активность"` признаки расположильсь следующим образом:

# %%
corr_rank = phik_overview.iloc[:,0].sort_values(ascending = False )
corr_rank
# Out:
# покупательская_активность              1.000000
# страниц_за_визит                       0.748769
# минут_за_предыдущий_месяц              0.685078
# минут_за_текущий_месяц                 0.575662
# маркет_актив_6_мес                     0.546370
# средний_просмотр_категорий_за_визит    0.539221
# акционные_покупки                      0.506991
# неоплаченные_продукты_штук_квартал     0.504845
# выручка_за_препредыдущий_месяц         0.495174
# популярная_категория                   0.298036
# выручка_за_предыдущий_месяц            0.227280
# ошибка_сервиса                         0.223697
# выручка_за_текущий_месяц               0.195470
# тип_сервиса                            0.132247
# длительность                           0.101767
# маркет_актив_тек_мес                   0.000000
# разрешить_сообщать                     0.000000
# Name: покупательская_активность, dtype: float64

# %% [markdown]
# создадим список для коэфф корр >0

# %%
#список для построения визуализаций с делением по таргету
describers_more_0=corr_rank.loc[(corr_rank.values < 1) & (corr_rank.values > 0)].index.tolist()
display (describers_more_0)
# Out:
# ['страниц_за_визит',
#  'минут_за_предыдущий_месяц',
#  'минут_за_текущий_месяц',
#  'маркет_актив_6_мес',
#  'средний_просмотр_категорий_за_визит',
#  'акционные_покупки',
#  'неоплаченные_продукты_штук_квартал',
#  'выручка_за_препредыдущий_месяц',
#  'популярная_категория',
#  'выручка_за_предыдущий_месяц',
#  'ошибка_сервиса',
#  'выручка_за_текущий_месяц',
#  'тип_сервиса',
#  'длительность']

# %% [markdown]
# ### Заключение по корреляционному анализу.
# Среди данных признаков мультиколлинеарность отсутствует
# В звершении построим визуализации данных корреляций

# %%
#найдем пересечение списков describers_more_0  и num_col_names(количественные признаки)
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

describers_interval = intersection(describers_more_0, num_col_names)

# %%
#Рассмотрим распределение признаков с  коэф корр >0
for i in describers_interval:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    fig = sns.histplot( data=df_market_file_new, x=i, hue = 'покупательская_активность'  ) 
    #fig.suptitle('Распределение признаков', fontweight ="bold") 
    #ax = sns.histplot( data=df_decreased, x=i, ax=axes[1])

# %% [markdown]
# Визуально наиболее информативными для классификации выглядят признаки:
#
# - страниц_за_визит
# - выручка за препредыдущий месяц
# - минут_за_предыдущий_месяц
# - минут_за_текущий_месяц
# - неоплаченные_продукты_штук_квартал

# %%
# посмотрим, что с популярной категорией и типом сервиса
my_plot = sns.countplot(x ='популярная_категория', data = df_market_file_new, hue = 'покупательская_активность')
my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=45);

# %%
my_plot = sns.countplot(x ='тип_сервиса', data = df_market_file_new, hue = 'покупательская_активность')
#my_plot.set_xticklabels(my_plot.get_xticklabels(), rotation=45);

# %% [markdown]
# У пользователей сохраняющих прежнюю активность выраженный интерес сосредоточен в категориях
# - мелкая бытовая техника и электроника
# - техника для красоты и здоровья
# - домашний текстиль
# - товары для детей
#
#
# Но посмотрим, что нам скажет SHAP, когда придет его время.

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# ### Пайплайн для подготовки данных с использованием ColumnTransformer

# %%
#константы
RANDOM_STATE = 58
TEST_SIZE = 0.25
#ф-ия подготовки данных
def prepare_data(df):
    #Закодирую вручную целевой признак чтобы понимать какой класс что значит
    df['покупательская_активность_бин'] = df['покупательская_активность'].apply(lambda x: 0 if x == 'Прежний уровень' else 1)
    # делим данные на тренировочные и тестовые
    X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['id','покупательская_активность', 'покупательская_активность_бин' ],  axis=1),
    df['покупательская_активность_бин'],    
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify = df['покупательская_активность']    
        )
    
    return  X_train, X_test, y_train, y_test

# %%
df_market_file_new
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1292  216643           Прежний уровень    стандарт                 да
# 1293  216644           Прежний уровень    стандарт                нет
# 1294  216645           Прежний уровень    стандарт                 да
# 1295  216646           Прежний уровень    стандарт                 да
# 1296  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
X_train, X_test, y_train, y_test = prepare_data(df_market_file_new)

# %%
# Пайплайн для подготовки данных
    
ohe_columns = [ 'тип_сервиса', 'разрешить_сообщать', 'популярная_категория' ]
num_columns = describers_interval

# SimpleImputer + OE
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)# ord_pipe done

# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first' , sparse=False) # запрещает исмпользовать handle_unknown='ignore' и drop='first' вместе
        )
    ]
)


# создаём общий пайплиайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
       # ('ord', ord_pipe, ohe_columns),
        ('ohe', ohe_pipe, ohe_columns),
        ('num', MinMaxScaler(), num_columns)
        
    ], 
    remainder='passthrough'
)

# %%
#посмотрим как выглядят трансформированные данные 
# не смог заставить работать на платформе практикума

#X_train_p = pd.DataFrame(
#    data_preprocessor.fit_transform(X_train),
#    columns=data_preprocessor.get_feature_names_out() # get_feature_names_out() ни так ни так get_feature_names()
#)
#X_train_p

# %% [markdown]
# ### Пайплайн для поиска лучшей модели c  подбором гиперпараметров
# В качестве метрики будет использована F1 мера т.к. она отражает баланс классов ошибок.

# %%
# создаём общий итоговый piplne - подготовка данных и модель 
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))    
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    
    # словарь для модели SVC()
    {
       
        'models': [SVC(
            random_state=RANDOM_STATE,
            kernel = 'poly'
    
        )],
        
        'models__degree':  range(4, 8),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
                    
        
    },
    # словарь для модели LogisticRegression()
      {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            #solver='saga',
            penalty='l1'
        )],
        'models__C':  range(1, 3),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
                    
        
    }
    
]

'''
oscv = OptunaSearchCV(
    pipe_final,
    parameters,
    cv=5,
    n_trials=20,
    scoring='roc_auc',
    random_state=RANDOM_STATE
)
'''

#randomized_search = RandomizedSearchCV(
grid_search = GridSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='f1',
    #random_state=RANDOM_STATE,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
# ...

# %% [markdown]
# После загрузки всех признаков сменился победитель теперь это
# SVC(degree=4, kernel='poly', random_state=58)
# и MinMaxScaler()
# Качество на трейне  0.8220
# Выведем результат работы gridsearch

# %%
result = pd.DataFrame(grid_search.cv_results_)
pd.set_option('display.max_colwidth', None)
print(result[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#     rank_test_score  \
# 46                1
# 58                2
# 45                3
# 57                4
# 61                5
# ..              ...
# 2                65
# 1                65
# 0                65
# 53               68
# 56               69
#
#                                                              param_models  \
# 46                          SVC(degree=4, kernel='poly', random_state=58)
# 58  LogisticRegression(penalty='l1', random_state=58, solver='liblinear')
# 45                          SVC(degree=4, kernel='poly', random_state=58)
# 57  LogisticRegression(penalty='l1', random_state=58, solver='liblinear')
# 61  LogisticRegression(penalty='l1', random_state=58, solver='liblinear')
# ..                                                                    ...
# 2                                 DecisionTreeClassifier(random_state=58)
# 1                                 DecisionTreeClassifier(random_state=58)
# ...

# %% [markdown]
# ### Подитог
# Будем использовать для работы
#
# LogisticRegression(penalty='l1', random_state=58, solver='liblinear'),
# 'models__C': 1,
# 'preprocessor__num': MinMaxScaler()

# %%
#ф-ия лучшей модели с применением лучшего скалера
def model_log_reg (df,  cat_col_names, num_col_names):
    
    
    ''' Разбивает датасет на тренировочную и тестовую выборки, кодирует и масштабирует входные признаки,
    создает обученные на тренировочной выборе экземляры классов 
    - model_log_reg - модель линейной регрессии
    - OHE_encoder - кодировщие OHE 
    - log_scaler -  нормализатор
    строит прогноз на данных тестовой выборки

    Args:
        df (DataFrame):Датасет с колонками вещественых и категориальных признаков, а так же целевая переменная.
        cat_col_names(list): список категориальных колонок для OHE
        num_col_names(list): список колличественных колонок 
        
        
    Returns:
        y_test(array) - значения целевой переменной у тренировочной выборки
        log_predictions (array) - предсказание модели на тестовой выборке
        model_log_reg - обученная модель
        OHE_encoder - обученный кодировщик
        log_scaler - обученный нормализатор
        X_train, y_train, X_test, y_test - данные для анализа вилиятельности факторов и расчёта метрик
        #y_pred_new_threshold - предсказание модели на тестовой выборке при нестандартном пороге класс-ии
        
    '''
    #Закодирую вручную целевой признак чтобы понимать какой класс что значит
    #df['покупательская_активность'] = df['покупательская_активность'].apply(lambda x: 0 if x == 'Прежний уровень' else 1)
    # делим данные на тренировочные и тестовые
    X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['id','покупательская_активность', 'покупательская_активность_бин' ],  axis=1),    
    df['покупательская_активность_бин'],    
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify = df['покупательская_активность_бин']    
        )
   
    OHE_encoder  = OneHotEncoder(drop='first', sparse=False) 
    #Отобранные порезультатам корр. анализа категориальыне признаки
    cat_col_names = ['популярная_категория', 'тип_сервиса', 'разрешить_сообщать' ]       #cat_col_names
    # обучим encoder
    OHE_encoder.fit(X_train[cat_col_names])
    # кодирование тренировочной выборки
    X_train_ohe = OHE_encoder.transform(X_train[cat_col_names])
    # обучим и преобразуем категориальные признаки из тренировочной выборки 
    #X_train_ohe = encoder.fit_transform(X_train[cat_col_names]) 
    # выполним преобразование категориальных признаков в тестовой выборке
    X_test_ohe = OHE_encoder.transform(X_test[cat_col_names])
    # сохраним в переменной encoder_col_names названия новых столбцов 
    encoder_col_names = OHE_encoder.get_feature_names()
    # создаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
    X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
    X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)
  
    
    # Инициализация scaler`a
    log_scaler = MinMaxScaler()
    # список всех количественных признаков из тренировочной выборки
    num_col_names = describers_interval
    # обучим и преобразуем количественные признаки из тренировочной выборки 
    X_train_scaled = log_scaler.fit_transform(X_train[num_col_names])
    # выполним преобразование количественных признаков в тестовой выборке
    X_test_scaled = log_scaler.transform(X_test[num_col_names])
    # создаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
    X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names)
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_col_names)

        # объединяем все преобразованные данные в тренировочный и тестовый датафреймы
        # сбрасываем индексы в датафрейме с числовыми индексами, чтобы избежать ошибок

    X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1)
    X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1)
 
    #инициализация модели
    model_log_reg = LogisticRegression(C=1, penalty='l1', random_state=RANDOM_STATE,
                                    solver='liblinear')
    
    #подбор коэффициентов регрессии#########
    
    model_log_reg.fit(X_train, y_train)
    
    #print('wn =', model_lr.coef_, 'w0=', model_lr.intercept_)
    #тестирование работы модели
    log_predictions =  model_log_reg.predict(X_test)
    log_y_test = y_test 
    
    #срока настройки порога классификации,  меняется по результатам анализа порога классификации
    #y_pred_new_threshold = (model_log_reg.predict_proba(X_test)[:, 1] >= 0.44).astype(int) 
    log_proba = model_log_reg.predict_proba(X_test)
    
    
    return  log_y_test, log_predictions,  model_log_reg, OHE_encoder, log_scaler, log_proba, X_test,\
    y_train, y_test

# %%
#Проверим как сработала лучшая модель коассификации на тестовых данных 
log_y_test, log_predictions,  model_log_reg, OHE_encoder, log_scaler, log_proba, X_test,\
   y_train, y_test = model_log_reg(df_market_file_new, 
                           df_market_file_new[['популярная_категория', 'тип_сервиса', 'разрешить_сообщать']],
                           describers_interval)

# %%
#Посчитаем F1 на тесте
f1_score(y_test, log_predictions)
# Out:
# 0.8706896551724138

# %% [markdown]
# ## Анализ важности признаков. Shap

# %%
#Теперь использием SHAP на луччшей модели.
explainer = shap.LinearExplainer(model_log_reg, X_test)
shap_values = explainer(X_test)

shap.plots.beeswarm(shap_values,  max_display=23 )

# %%
shap.plots.bar(shap_values, max_display=23)

# %% [markdown]
# По результатам анализа отражен общий вклад признаков в прогноз модели, можем выделить  3 группы признаков:
# - 1 **признаки с наиболее сильным влиянием на прогноз, средние значения shap > 0.5**
# средний_просмотр_категорий_за_визит - 0.51
# страниц_за_визит - 0.51
# минут_за_предыдущий_месяц - 0.51
#
#
# - 2 **признаки  со средним влиянием, средние значения shap >0.3 &  <0.5**:
# акционные_покупки,  минут_за_текущий_месяц, маркет_актив_6_мес
# неоплаченные_продукты_штук_квартал.
#
#
# - 3 **признаки  слабо влияющие, средние значения shap > 0 & < 0.3**:
# выручка_за_препредыдущий_месяц, популярная_категория,выручка_за_предыдущий_месяц , маркет_актив_тек_мес, длительность.

# %% [markdown]
# ### Выводы по анализу важности признаков
# Здесь используем уловность класс 1 - покупательская активность вероятнее снизится, класс 0 - покупательская активность скорре останется без изменений. Рассмотрим признаки с сильным и средним влиянием. Разберем в порядке убывания важности.
#
#     - 1 При высоких значениях среднего количества просмотрои категорий за визит(`средний_просмотр_категорий_за_визит`) повышается вероятность, что клиент будет отнесен к  классу 0, при низких соответсвенно в классу 1.
#     - 2 При высоких значениях среднего количества просмотров страниц за визит (`страниц_за_визит`) повышается вероятность, что клиент  будет отнесен к классу 0.
#     - 3 При высоких значениях количества минут проведенных на сайте за предыдущий месяц (`минут_за_предыдущий_месяц`)  повышается вероятность, что клиент  будет отнесен к классу 0.
#     - 4 При высоких значениях среднемесячной доли покупок по акции от общего числа покупок ('акционные_покупки') повышается вероятность, что клиент  будет отнесен к классу 1.
#     - 5  При высоких значениях количества минут проведенных на сайте за текущий месяц (`минут_за_текущтй_месяц`)  повышается вероятность, что клиент  будет отнесен к классу 0.
#     - 6 При высоких значениях среднемесячное количества маркетинговых коммуникаций компании('маркет_актив_6_мес') повышается вероятность, что клиент  будет отнесен к классу 0.
#     - 7 При высоких значениях количества неоплаченного товара в корзине(`неоплаченные_продукты_штук_квартал`)  повышается вероятность, что клиент  будет отнесен к классу 1.
#     - 8 Низкие значения выручки за препредыдущий месяц склоняет вероятность, что клиент  будет отнесен к классу 1
#     - 9 Доминирование категории мелкая бытовая техника и элетроника тповышает вероятность, что клиент  будет отнесен к классу 0
#
#    На основе данных выводов возможно сформулировать следующие рекомендации.
#
# - Первые 2 признака - связаны с ассортиментом товаров, чем больше интерсных прделождений тем вероятнее сохранять интерес.
# Логичным образом к ним присоедиянятся и признак количество проведенных минут сайте.
# - Закономерно, что многие стремятся минимизировать затраты и интересуются акционными прделожениями, и их активность снижается если акционные мероприятия становятся реже.
# - Низкое количество маркетинговых коммуникаций негативно влияет на покупательскую активность.
# - Если клиент накапливает в корзине неоплаченные товары это признак, что его активность может сократиться, возможно следует анализировать такие "накопления" и планировать маркетинговые акции с их учетом.

# %% [markdown]
# ## Сегментация покупателей

# %%
#Восстановим X_test и добавим в него вероятности снижения покупательской активности
X_train, X_test, y_train, y_test = train_test_split(
    df_market_file_new,
    df_market_file_new['покупательская_активность_бин'],    
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify = df_market_file_new['покупательская_активность_бин']    
        )

#Добавим вероятность классификации в X_test
prob_only_for_1_class =np.delete(log_proba,0, axis=1)
X_test['вероятность_классификации_активность_снизилась'] = prob_only_for_1_class
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Добавм данные по прибыльности клиентов
X_test_full = pd.merge(X_test, df_money, how="left", on="id")

# %%
#Рассмотрим скаттерплот связки `вероятность_классификации_активность_снизилась` и `прибыль`
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(data=X_test_full, x="вероятность_классификации_активность_снизилась", y="прибыль").\
set(title='Диаграмма рассеяния вероятности снижения покупательской активности и прибыльности клиента');

# %% [markdown]
#  На основе данного графика можно выделить группу с высокой вероятностью отнесения к классу 1(активность снизилась), вероятность > 0.8 и прибылью свыше 2. Отберем такой сегмент. Для сравнения отберем сегмент для которого прогнозируется низкая вероятность снижения покупательской активности менее 0.2 и прибыли более 2.

# %%
segment_decreasing_high_probability = X_test_full.query('вероятность_классификации_активность_снизилась > 0.8 &\
                                                         прибыль >2')
segment_decreasing_low_probability = X_test_full.query('вероятность_классификации_активность_снизилась > 0.2 &\
                                                         прибыль >2 ')

# %%
#Составим список признаков на основе данных shap со средней и высокой влиятельностью
# построим гистограммы для данных сегментов 
shap_list = ['средний_просмотр_категорий_за_визит', 'страниц_за_визит', 'минут_за_предыдущий_месяц', 
       'акционные_покупки', 'минут_за_текущий_месяц', 'маркет_актив_6_мес', 'неоплаченные_продукты_штук_квартал']
print ('Гистограммы для признаков на основе данных shap со средней и высокой влиятельностью, красным для сегмента,\
где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.\
Данные по клиентам средней и высокой прибыльности(более 2) ')
for i in shap_list:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    #title_string = 'Распределение признака '+ i+' по сегментам наименее(зеленый цвет) и наиболе(красный цвет) вероятного\
    #снижения покупательской активности'
    #fig. suptitle (title_string)
    #fig = sns.histplot( data=df_market_file_new, x=i, hue = 'покупательская_активность' ) 
    fig = sns.histplot( data=segment_decreasing_high_probability, color = 'red', x=i)
    fig = sns.histplot( data=segment_decreasing_low_probability, color = 'green', x=i)
# Out:
# Гистограммы для признаков на основе данных shap со средней и высокой влиятельностью, красным для сегмента,где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.Данные по клиентам средней и высокой прибыльности(более 2)

# %% [markdown]
# Надежное отличие наблюдается в следующих признаках
# - `средний_просмотр_категорий_за_визит` для сегмента, которому прогнозируется высоковероятное снижение активности среднее количество категорий не превышает 4х в то время как для противоположного по веротности сегемента модет бытть более 4
# - `страниц_за_визит` еще более информативное различие клиенты сегмента высоковероятного снижения активности просматривают выраженно меньше траниц со средним около 4, против среднего около 7 для сегмента антагониста
# - `минут_за_предыдущий_месяц` менее выраженное отличие, клиенты сегмента высоковероятного снижения активности тратят меньше времени на сайте..

# %%
# посмотрим, что с популярной категорией и типом сервиса
print ('Гистограммы для признаков популярная категория и тип сервиса, красным для сегмента,\
где активность наиболее вероятно снизится, зеленым для для сегмента активность наименее вероятно снизится.\
Данные по клиентам средней и высокой прибыльности(более 2) ')
cat_list = ['популярная_категория','тип_сервиса']
for i in cat_list:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    fig = sns.countplot( data=segment_decreasing_high_probability, color = 'red', x=i, ax=axes[0])
    axes[0].tick_params(axis='x', rotation=45)
    ax = sns.countplot( data=segment_decreasing_low_probability, color = 'green', x=i,ax=axes[1])
    plt.xticks(rotation=45)
# Out:
# Гистограммы для признаков популярная категория и тип сервиса, красным для сегмента,где активность наиболее вероятно снизится, зеленым для для сегмента активность наименее вероятно снизится.Данные по клиентам средней и высокой прибыльности(более 2)

# %% [markdown]
# Не определяются выраженные различия для данных признаков...

# %%
#Поднимем уровень прибыльности клиентов до 3.5 и проведем аналогичное рассмотрение.
segment_decreasing_high_probability_high_earn = X_test_full.query('вероятность_классификации_активность_снизилась > 0.8 &\
                                                         прибыль >3.5')
segment_decreasing_low_probability_high_earn = X_test_full.query('вероятность_классификации_активность_снизилась < 0.2 &\
                                                         прибыль >3.5')

# %%
# построим гистограммы для данных сегментов 
print ('Гистограммы для признаков на основе данных shap со средней и высокой влиятельностью, красным для сегмента,\
где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.\
Более высокоприбыльный сегмент, величина прибыльности клиентов более 3.5')
for i in shap_list:
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,5))
    fig = sns.histplot( data=segment_decreasing_high_probability_high_earn, color = 'red', x=i)
    fig = sns.histplot( data=segment_decreasing_low_probability_high_earn, color = 'green', x=i)
# Out:
# Гистограммы для признаков на основе данных shap со средней и высокой влиятельностью, красным для сегмента,где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.Более высокоприбыльный сегмент, величина прибыльности клиентов более 3.5

# %% [markdown]
# Повышение уровня прибыльности сделало картину отличий более контрастной.
# Сформулируем выводы.
# - `средний_просмотр_категорий_за_визит` для сегмента, которому прогнозируется высоковероятное снижение активности доминирует среднее количество категорий 2-3  в то время как для противоположного по вероятности сегемента 3-5.
# - `страниц_за_визит` здесь еще более четким стало различие - клиенты сегмента высоковероятного снижения активности просматривают 1-5 страниц, против 6-13  для сегмента антагониста по вероятности класса авктивности.
# - `минут_за_предыдущий_месяц` контрастное отличие, клиенты сегмента высоковероятного снижения активности тратят меньше времени на сайте их средее время около 8 против 16ти минут для клиентов низковероятного снижения активности.
#
# - появился контраст в признаке `минут_за_текущий_месяц`ситуация похожа на предыдущий признак клиенты сегмента высоковероятного снижения активности тратят меньше времени на сайте их средее время около 10 против 15ти минут для клиентов наменее вероятно снижущих активность..
#
#
# - добавился контраст в `маркет_актив_мес` если среднеее количество коммуникаций не более 2.3-4.3 то вероятнность того, что клиент снизит активность повышается, а вот если 4-6 то скорее не снизит.
#
# - Накопление свыше 5 неоплаченых покупок характерно для клиентов высоковероятного снижения активности.

# %%
# посмотрим, что с популярной категорией и типом сервиса
print ('Гистограммы для признаков популярная категория и тип сервиса, красным для сегмента,\
где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.\
Данные по клиентам более высокой прибыльности(более 3.5) ')
cat_list = ['популярная_категория','тип_сервиса', 'разрешить_сообщать']
for i in cat_list:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    fig = sns.countplot( data=segment_decreasing_high_probability_high_earn, color = 'red', x=i, ax=axes[0])
    axes[0].tick_params(axis='x', rotation=90)
    ax = sns.countplot( data=segment_decreasing_low_probability_high_earn, color = 'green', x=i,ax=axes[1])
    plt.xticks(rotation=90)
# Out:
# Гистограммы для признаков популярная категория и тип сервиса, красным для сегмента,где активность наиболее веротно снизится, зеленым для для сегмента активность наименее вероятно снизится.Данные по клиентам более высокой прибыльности(более 3.5)

# %% [markdown]
# В сегменте наиболее веротятного снижения покупательской активности наиболее выражено проявился сниженный интерес в категориях мелкая бытовая техника и электроника, техника для красоты и здоровья. По типу сервиса - наиболее вероятно ожидать снижение активности в типе стандарт.

# %% [markdown]
# Из всего этого сформулирую  несколько  рекомендаций.
# 1. Важно поддерживать интерес клиентов - быть предствительным местом, адекватным трендам потребления, с разнообразным выбором товаров, повышенное внимание нужно сосредоточить в предствительности категории товаров `мелкая бытовая техника и электроника` и `техника для красоты и здоровья`.
# 2. Чтобы удерживать внимание клиентов возможно стоит расмотреть увеличение функционала сайта - например положительно скажется  снабжение карточек товаров рекомендательными ссылками по типу предложения аналогов в сторону более и менее однокласных вещй и/или необходимых расходников...
# 3. Важно поддерживать баланс в маркетинговых коммуникациях с клиентом,  напоминать о себе по возможности деликатнее. Но далать это ни часто ни редко, как показал анализ - положительно сказывается количество  среднемесячных коммуникаций около 5.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Задача проекта сфомулирована следующим образом:
# Разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
# Исходные данные содержались в 4х файлах
# `market_file.csv`(df_market_file) Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведени.
# `market_money.csv`(df_market_money) Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# `market_time.csv`(df_market_time) Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# `money.cs`(df_money) Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# На этапе предобработки переименованы колонки в соответсвии со стандартными требованиями.
# Обработаны обнаруженные неявные дубликаты в категориальных признаках
#
# На этапе исследовательского внвлиза данных построены распределения количественных признаков, заменены медианой артефактно большие значения в датасете df_market_money
#
# Объединенеие дынных проведено в два этапа. Сначала добавили выручку из df_market_money в df_market_file отдельными столбцами по каждому из 3 месяцев.Затем  данные о времени проведенном на сайте из df_market_time в df_market_file отдельными столбцами по каждому из 2 месяцев.
#
# Проведен корреялционнный анализ признаков методом phik.  Среди  признаков мультиколлинеарность отсутствует.
# Построено сравнение распределений признаков по таргету.
#
# На этапе применения пайплайнов создан пайплайн для подготовки данных содержащий категориальный кодировщик OHE
# и скалер MinMaxScaler. Данные преобразование включены в ColumnTransformer
#
# Создан пайплайн для поиска лучшей модели c подбором гиперпараметров.
# В качестве метрики  использована F1 мера т.к. она отражает баланс классов ошибок.
# С помощию перебора по сетке GridSearchCV проверены модели со следующими гиперпараметрами:
# - DecisionTreeClassifier models__max_depth': range(2, 5), models__max_features': range(2, 5);
# - KNeighborsClassifier models_n_neighbors': range(2, 5);
# - LogisticRegression(penalty='l1', random_state=58, solver='liblinear'), models__C':  range(1, 5);
# - SVC(random_state=RANDOM_STATE, kernel = 'poly models__degree':  range(4, 8)
# для всех моделей применен StandardScaler() и MinMaxScaler()
#
# Выбрана модель
#
# LogisticRegression(penalty='l1', random_state=58, solver='liblinear'),
# 'models__C': 1,
# скалер -  MinMaxScaler()
# f1 метрика на тесте 0.8706
#
# Анализ важности признаков при помощи Shap определил 3 группы признаков:
#
# - 1 **признаки с наиболее сильным влиянием на прогноз, средние значения shap > 0.5**
# средний_просмотр_категорий_за_визит - 0.51
# страниц_за_визит - 0.51
# минут_за_предыдущий_месяц - 0.5
#
#
# - 2 **признаки  со средним влиянием, средние значения shap >0.3 &  <0.5**:
# акционные_покупки,  минут_за_текущий_месяц, маркет_актив_6_мес
# неоплаченные_продукты_штук_квартал.
#
#
# - 3 **признаки  слабо влияющие, средние значения shap > 0 & < 0.3**:
# выручка_за_препредыдущий_месяц, популярная_категория,выручка_за_предыдущий_месяц , маркет_актив_тек_мес, длительность.
#
# Сформулироапны следующие выводы по анализу важности признаков.
# Здесь используем уловность класс 1 - покупательская активность вероятнее снизится, класс 0 - покупательская активность скорре останется без изменений. Рассмотрим признаки с сильным и средним влиянием. Разберем в порядке убывания важности.
#
# - 1 При высоких значениях среднего количества просмотрои категорий за визит(`средний_просмотр_категорий_за_визит`) повышается вероятность, что клиент будет отнесен к  классу 0, при низких соответсвенно в классу 1.
# - 2 При высоких значениях среднего количества просмотров страниц за визит (`страниц_за_визит`) повышается вероятность, что клиент  будет отнесен к классу 0.
# - 3 При высоких значениях количества минут проведенных на сайте за предыдущий месяц (`минут_за_предыдущий_месяц`)  повышается вероятность, что клиент  будет отнесен к классу 0.
# - 4 При высоких значениях среднемесячной доли покупок по акции от общего числа покупок ('акционные_покупки') повышается вероятность, что клиент  будет отнесен к классу 1.
# - 5  При высоких значениях количества минут проведенных на сайте за текущий месяц (`минут_за_текущтй_месяц`)  повышается вероятность, что клиент  будет отнесен к классу 0.
# - 6 При высоких значениях среднемесячное количества маркетинговых коммуникаций компании('маркет_актив_6_мес') повышается вероятность, что клиент  будет отнесен к классу 0.
# - 7 При высоких значениях количества неоплаченного товара в корзине(`неоплаченные_продукты_штук_квартал`)  повышается вероятность, что клиент  будет отнесен к классу 1.
# - 8 Низкие значения выручки за препредыдущий месяц склоняет вероятность, что клиент  будет отнесен к классу 1
# - 9 Доминирование категории мелкая бытовая техника и элетроника тповышает вероятность, что клиент  будет отнесен к классу 0
#
#
# На основе данных выводов возможно сформулировать следующие рекомендации:
# Первые 2 признака - связаны с ассортиментом товаров, чем больше интерсных прделождений тем вероятнее сохранять интерес. Логичным образом к ним присоедиянятся и признак количество проведенных минут сайте.
# Закономерно, что многие стремятся минимизировать затраты и интересуются акционными прделожениями, и их активность снижается если акционные мероприятия становятся реже.
# Низкое количество маркетинговых коммуникаций негативно влияет на удержание клиентов.
# Выявлен значительный интерес к категориии товаров 'Мелкая бытовая техника и элкетроника' чем он будет разнообразнее тем веротнее удерживать клиентов.
# Если клиент накапливает в корзине неоплаченные товары это признак, что его активность может сократиться, возможно следует анализировать такие "накопления" и планировать маркетинговые акции с их учетом.
#
#
# **Сегментация покупателей**
#
# На основе вероятностей классификации  клиента  классом 1(т.е. покупательская активность снизится) и данных о прибыльности клиентов определены сегменты для которых
# прогнозируется высокая веротность снижения покупательской активности (вероятность класса 1 более 0.8)
# и сегмент для которого определена низкая верояность снижения покупательской активности (вероятность класса 1 менее 0.2)
# Прибыльность на первом этапе рассмотрения начиналсь от 2 - т.е. средняя и высокая
# На втором этапе от 3.5() более высокоприбыльный сегмент.
#
# Рассмотрены  признаки классификации с важностью по Shap > 0.3
#
#
# Повышение уровня прибыльности сделало картину отличий более контрастной.
# Сформулируем выводы.
# - `средний_просмотр_категорий_за_визит` для сегмента, которому прогнозируется высоковероятное снижение активности доминирует среднее количество категорий 2-3  в то время как для противоположного по вероятности сегемента 3-5.
# - `страниц_за_визит` здесь еще более четким стало различие - клиенты сегмента высоковероятного снижения активности просматривают 1-5 страниц, против 6-13  для сегмента антагониста по вероятности класса авктивности.
# - `минут_за_предыдущий_месяц` контрастное отличие, клиенты сегмента высоковероятного снижения активности тратят меньше времени на сайте их средее время около 8 против 16ти минут для клиентов низковероятного снижения активности.
#
# - появился контраст в признаке `минут_за_текущий_месяц`ситуация похожа на предыдущий признак клиенты сегмента высоковероятного снижения активности тратят меньше времени на сайте их средее время около 10 против 15ти минут для клиентов наменее вероятно снижущих активность..
#
# - добавился контраст в `маркет_актив_мес` если среднеее количество коммуникаций не более 2.3-4.3 то вероятнность того, что клиент снизит активность повышается, а вот если 4-6 то скорее не снизит.
#
# - Накопление свыше 5 неоплаченых покупок характерно для клиентов высоковероятного снижения активности.
#
# По результатам выводов сформулирую рекомендации по снижению вероятности изменения покупательской активности на негативную:
#
# 1. Важно поддерживать интерес клиентов - быть предствительным местом, адекватным трендам потребления, с разнообразным выбором товаров, повышенное внимание нужно сосредоточить в предствительности категории товаров `мелкая бытовая техника и электроника` и `техника для красоты и здоровья`.
# 2. Чтобы удерживать внимание клиентов возможно стоит расмотреть увеличение функционала сайта - например положительно скажется  снабжение карточек товаров рекомендательными ссылками по типу предложения аналогов в сторону более и менее однокласных вещй и/или необходимых расходников...
# 3. Важно поддерживать баланс в маркетинговых коммуникациях с клиентом,  напоминать о себе по возможности деликатнее. Но далать это ни часто ни редко, как показал анализ - положительно сказывается количество  среднемесячных коммуникаций около 5.
